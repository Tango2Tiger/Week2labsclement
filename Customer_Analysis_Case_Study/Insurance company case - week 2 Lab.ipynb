# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
file1 = pd.read_csv('Data/file1.csv')
file2 = pd.read_csv('Data/file2.csv')
file3 = pd.read_csv('Data/file3.csv')

# %%
df1=pd.DataFrame(file1)
df2=pd.DataFrame(file2)
df3=pd.DataFrame(file3)


df1.rename(columns={'Customer':'customer','ST':'state',
                    'GENDER':'gender',"Education":"education", 
                    "Customer Lifetime Value":"lifetime val","Income": "income",
                    "Monthly Premium Auto":"monthly premium",
                    "Number of Open Complaints":"open complaints","Policy Type":"policy",
                    "Vehicle Class":"vehicle class","Total Claim Amount":"total claim amount"}, inplace=True )

df2.rename(columns={'Customer':'customer','ST':'state',
                    'GENDER':'gender',"Education":"education", 
                    "Customer Lifetime Value":"lifetime val","Income": "income",
                    "Monthly Premium Auto":"monthly premium",
                    "Number of Open Complaints":"open complaints","Policy Type":"policy",
                    "Vehicle Class":"vehicle class","Total Claim Amount":"total claim amount"}, inplace=True)

df3.rename(columns={'Customer':'customer','State':'state',
                    'Gender':'gender',"Education":"education", 
                    "Customer Lifetime Value":"lifetime val","Income": "income",
                    "Monthly Premium Auto":"monthly premium",
                    "Number of Open Complaints":"open complaints","Policy Type":"policy",
                    "Vehicle Class":"vehicle class","Total Claim Amount":"total claim amount"}, inplace=True )

# %%
df=pd.concat([df1,df2,df3], axis=0)
df=df.reset_index(drop=True)

# %%
df
# Out:
#      customer       state  gender             education  lifetime val  \
# 0     RB50392  Washington    Male                Master           NaN
# 1     QZ44356     Arizona  Female              Bachelor        6980.0
# 2     AI49188      Nevada  Female              Bachelor       12887.0
# 3     WW63253  California    Male              Bachelor        7646.0
# 4     GA49547  Washington    Male  High School or Below        5363.0
# ...       ...         ...     ...                   ...           ...
# 9130  LA72316  California    Male              Bachelor       23406.0
# 9131  PK87824  California  Female               College        3097.0
# 9132  TD14365  California    Male              Bachelor        8164.0
# 9133  UP19263  California    Male               College        7524.0
# 9134  Y167826  California    Male               College        2612.0
#
#        income  monthly premium open complaints          policy  vehicle class  \
# 0         0.0           1000.0          1/0/00   Personal Auto  Four-Door Car
# 1         0.0             94.0          1/0/00   Personal Auto  Four-Door Car
# 2     48767.0            108.0          1/0/00   Personal Auto   Two-Door Car
# 3         0.0            106.0          1/0/00  Corporate Auto            SUV
# 4     36357.0             68.0          1/0/00   Personal Auto  Four-Door Car
# ...       ...              ...             ...             ...            ...
# 9130  71941.0             73.0               0   Personal Auto  Four-Door Car
# 9131  21604.0             79.0               0  Corporate Auto  Four-Door Car
# 9132      0.0             85.0               3  Corporate Auto  Four-Door Car
# 9133  21941.0             96.0               0   Personal Auto  Four-Door Car
# 9134      0.0             77.0               0  Corporate Auto   Two-Door Car
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 9130          198.234764
# 9131          379.200000
# 9132          790.784983
# 9133          691.200000
# 9134          369.600000
#
# [9135 rows x 11 columns]

# %%
def stateclean(state):
    if state=="Cali":
        return "California"
    elif state=="AZ":
        return "Arizona"
    elif state=="WA":
        return "Washington"
    else:
        return state

df["state"]=df["state"].apply(stateclean)
df
# Out:
#       customer       state gender             education lifetime val   income  \
# 0      RB50392  Washington    NaN                Master          NaN      0.0
# 1      QZ44356     Arizona      F              Bachelor   697953.59%      0.0
# 2      AI49188      Nevada      F              Bachelor  1288743.17%  48767.0
# 3      WW63253  California      M              Bachelor   764586.18%      0.0
# 4      GA49547  Washington      M  High School or Below   536307.65%  36357.0
# ...        ...         ...    ...                   ...          ...      ...
# 12069  LA72316  California      M              Bachelor  23405.98798  71941.0
# 12070  PK87824  California      F               College  3096.511217  21604.0
# 12071  TD14365  California      M              Bachelor  8163.890428      0.0
# 12072  UP19263  California      M               College  7524.442436  21941.0
# 12073  Y167826  California      M               College  2611.836866      0.0
#
#        monthly premium open complaints          policy  vehicle class  \
# 0               1000.0          1/0/00   Personal Auto  Four-Door Car
# 1                 94.0          1/0/00   Personal Auto  Four-Door Car
# 2                108.0          1/0/00   Personal Auto   Two-Door Car
# 3                106.0          1/0/00  Corporate Auto            SUV
# 4                 68.0          1/0/00   Personal Auto  Four-Door Car
# ...                ...             ...             ...            ...
# 12069             73.0               0   Personal Auto  Four-Door Car
# 12070             79.0               0  Corporate Auto  Four-Door Car
# 12071             85.0               3  Corporate Auto  Four-Door Car
# 12072             96.0               0   Personal Auto  Four-Door Car
# 12073             77.0               0  Corporate Auto   Two-Door Car
#
#        total claim amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 11 columns]

# %%
def genderclean(gender):
    if gender in ['M', 'Male',"nan"]:
        return 'Male'
    elif gender in ['F', 'female',"Femal","nan"]:
        return 'Female'
    else:
        return "Male"
    

df["gender"]=df["gender"].apply(genderclean)
df
# Out:
#       customer       state  gender             education lifetime val  \
# 0      RB50392  Washington    Male                Master          NaN
# 1      QZ44356     Arizona  Female              Bachelor   697953.59%
# 2      AI49188      Nevada  Female              Bachelor  1288743.17%
# 3      WW63253  California    Male              Bachelor   764586.18%
# 4      GA49547  Washington    Male  High School or Below   536307.65%
# ...        ...         ...     ...                   ...          ...
# 12069  LA72316  California    Male              Bachelor  23405.98798
# 12070  PK87824  California  Female               College  3096.511217
# 12071  TD14365  California    Male              Bachelor  8163.890428
# 12072  UP19263  California    Male               College  7524.442436
# 12073  Y167826  California    Male               College  2611.836866
#
#         income  monthly premium open complaints          policy  \
# 0          0.0           1000.0          1/0/00   Personal Auto
# 1          0.0             94.0          1/0/00   Personal Auto
# 2      48767.0            108.0          1/0/00   Personal Auto
# 3          0.0            106.0          1/0/00  Corporate Auto
# 4      36357.0             68.0          1/0/00   Personal Auto
# ...        ...              ...             ...             ...
# 12069  71941.0             73.0               0   Personal Auto
# 12070  21604.0             79.0               0  Corporate Auto
# 12071      0.0             85.0               3  Corporate Auto
# 12072  21941.0             96.0               0   Personal Auto
# 12073      0.0             77.0               0  Corporate Auto
#
#        vehicle class  total claim amount
# 0      Four-Door Car            2.704934
# 1      Four-Door Car         1131.464935
# 2       Two-Door Car          566.472247
# 3                SUV          529.881344
# 4      Four-Door Car           17.269323
# ...              ...                 ...
# 12069  Four-Door Car          198.234764
# 12070  Four-Door Car          379.200000
# 12071  Four-Door Car          790.784983
# 12072  Four-Door Car          691.200000
# 12073   Two-Door Car          369.600000
#
# [12074 rows x 11 columns]

# %%
def cleanedu(edu):
    if edu=="Bachelors":
        return "Bachelor"
    elif edu==np.nan:
        pass
    else:
        return edu

df["education"]=df["education"].apply(cleanedu)

# %%
def cleanint(val):
    if str(val).endswith("%"):
        val = int(round(float(val.rstrip(val[-1]))/100,0))
        return val
    else:
        try:
            return int(round(val,0))
        except ValueError:
            return val

df["lifetime val"] = df["lifetime val"].apply(cleanint)
df
# Out:
#       customer       state  gender             education  lifetime val  \
# 0      RB50392  Washington    Male                Master           NaN
# 1      QZ44356     Arizona  Female              Bachelor        6980.0
# 2      AI49188      Nevada  Female              Bachelor       12887.0
# 3      WW63253  California    Male              Bachelor        7646.0
# 4      GA49547  Washington    Male  High School or Below        5363.0
# ...        ...         ...     ...                   ...           ...
# 12069  LA72316  California    Male              Bachelor       23406.0
# 12070  PK87824  California  Female               College        3097.0
# 12071  TD14365  California    Male              Bachelor        8164.0
# 12072  UP19263  California    Male               College        7524.0
# 12073  Y167826  California    Male               College        2612.0
#
#         income  monthly premium open complaints          policy  \
# 0          0.0           1000.0          1/0/00   Personal Auto
# 1          0.0             94.0          1/0/00   Personal Auto
# 2      48767.0            108.0          1/0/00   Personal Auto
# 3          0.0            106.0          1/0/00  Corporate Auto
# 4      36357.0             68.0          1/0/00   Personal Auto
# ...        ...              ...             ...             ...
# 12069  71941.0             73.0               0   Personal Auto
# 12070  21604.0             79.0               0  Corporate Auto
# 12071      0.0             85.0               3  Corporate Auto
# 12072  21941.0             96.0               0   Personal Auto
# 12073      0.0             77.0               0  Corporate Auto
#
#        vehicle class  total claim amount
# 0      Four-Door Car            2.704934
# 1      Four-Door Car         1131.464935
# 2       Two-Door Car          566.472247
# 3                SUV          529.881344
# 4      Four-Door Car           17.269323
# ...              ...                 ...
# 12069  Four-Door Car          198.234764
# 12070  Four-Door Car          379.200000
# 12071  Four-Door Car          790.784983
# 12072  Four-Door Car          691.200000
# 12073   Two-Door Car          369.600000
#
# [12074 rows x 11 columns]

# %%
df=df.drop_duplicates()
df=df.reset_index(drop=True)
df
# Out:
#      customer       state  gender             education  lifetime val  \
# 0     RB50392  Washington    Male                Master           NaN
# 1     QZ44356     Arizona  Female              Bachelor        6980.0
# 2     AI49188      Nevada  Female              Bachelor       12887.0
# 3     WW63253  California    Male              Bachelor        7646.0
# 4     GA49547  Washington    Male  High School or Below        5363.0
# ...       ...         ...     ...                   ...           ...
# 9130  LA72316  California    Male              Bachelor       23406.0
# 9131  PK87824  California  Female               College        3097.0
# 9132  TD14365  California    Male              Bachelor        8164.0
# 9133  UP19263  California    Male               College        7524.0
# 9134  Y167826  California    Male               College        2612.0
#
#        income  monthly premium open complaints          policy  vehicle class  \
# 0         0.0           1000.0          1/0/00   Personal Auto  Four-Door Car
# 1         0.0             94.0          1/0/00   Personal Auto  Four-Door Car
# 2     48767.0            108.0          1/0/00   Personal Auto   Two-Door Car
# 3         0.0            106.0          1/0/00  Corporate Auto            SUV
# 4     36357.0             68.0          1/0/00   Personal Auto  Four-Door Car
# ...       ...              ...             ...             ...            ...
# 9130  71941.0             73.0               0   Personal Auto  Four-Door Car
# 9131  21604.0             79.0               0  Corporate Auto  Four-Door Car
# 9132      0.0             85.0               3  Corporate Auto  Four-Door Car
# 9133  21941.0             96.0               0   Personal Auto  Four-Door Car
# 9134      0.0             77.0               0  Corporate Auto   Two-Door Car
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 9130          198.234764
# 9131          379.200000
# 9132          790.784983
# 9133          691.200000
# 9134          369.600000
#
# [9135 rows x 11 columns]

# %%
df=df.drop("customer",axis=1)

# %%
"""

clean the number of open complaints and extract the middle number which is changing between records. 
pay attention that the number of open complaints is a categorical feature.

rearranging columns (if needed)

Working with data types – Check the data types of all the columns and fix the incorrect ones 
(for ex. customer lifetime value and number of open complaints ). 
Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
"""
